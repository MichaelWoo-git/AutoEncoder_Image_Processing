# %% [markdown]
# __Imports__

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import keras
import tensorflow_datasets as tfds

# %% [markdown]
# ### Load in the data__
# * Splits the data
# * Shuffle the data

# %% [markdown]
# __Batch_size=-1 to get the full dataset in NumPy arrays from the returned tf.Tensor object__

# %%
mnist_test,mnist_val,mnist_train = tfds.load(name="mnist_corrupted/spatter",
                                             split=["train[:10%]", "train[10%:25%]", "train[25%:]"],
                                             batch_size=-1,
                                             shuffle_files=True
                                            )

# %% [markdown]
# __tfds.as_numpy return a generator that yields NumPy array records out of a tf.data.Dataset__

# %%
# tfds.as_numpy return a generator that yields NumPy array records out of a tf.data.Dataset
mnist_train = tfds.as_numpy(mnist_train) 
mnist_val = tfds.as_numpy(mnist_val) 
mnist_test = tfds.as_numpy(mnist_test)

# %% [markdown]
# __Seperate the x and y__

# %%
x_train, y_train = mnist_train["image"], mnist_train["label"]
x_valid,y_valid = mnist_val["image"], mnist_val["label"]
x_test, y_test = mnist_test["image"], mnist_test["label"]

# %% [markdown]
# __Check lengths__

# %%
print("Train set size: ", len(x_train))
print("Valid set size: ", len(x_valid))
print("Test set size: ", len(x_test))
# Out:
# Train set size:  45000
# Valid set size:  9000
# Test set size:  6000

# %% [markdown]
# __Data Normalization__

# %%
# Normalize values
x_train = x_train/255
x_valid = x_valid/255
x_test = x_test/255

# %% [markdown]
# __Visualize the Data__

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(x_train[i], cmap=plt.cm.binary, interpolation='nearest')
    # label the image with the target value
    ax.text(0, 7, str(y_train[i]))

# %% [markdown]
# ### Processing Data

# %% [markdown]
# __Accuracy Function__

# %%
def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

# %% [markdown]
# __Always a good habit to randomized seeds__

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# __Autoencoder Model__

# %% [markdown]
# __Encoder__

# %%
denoising_encoder = keras.models.Sequential([
 keras.layers.Reshape( [28, 28, 1], input_shape=[28,28] ),
 keras.layers.Conv2D(filters = 16, kernel_size = (3, 3), activation='selu', padding='same'),
 keras.layers.MaxPooling2D(pool_size = (2, 2),strides=(2,2),padding='valid'),
 keras.layers.GaussianNoise(0.3),
 keras.layers.Conv2D(filters = 8, kernel_size = (3, 3), activation='selu', padding='same'),
 keras.layers.MaxPooling2D(pool_size = (2, 2),strides=(2,2),padding='same'),
 keras.layers.Conv2D(filters = 8, kernel_size = (3, 3), activation='selu', padding='same'),
 keras.layers.MaxPooling2D(pool_size = (2, 2),strides=(2,2),padding='same'),
 keras.layers.GaussianNoise(0.3),
 keras.layers.Flatten(),
 keras.layers.Dense(256, activation="selu"),
 keras.layers.GaussianNoise(0.5),
 keras.layers.Dense(28*28, activation="selu"),
 keras.layers.Reshape( [28, 28,1] )

])

# %% [markdown]
# __Decoder__

# %%
denoising_decoder = keras.models.Sequential([
 keras.layers.Conv2DTranspose(8, kernel_size = 3, activation='selu', padding='valid',input_shape=[28,28,1]),
#  keras.layers.Conv2DTranspose(16, kernel_size=3, strides=2, padding="SAME", activation="selu" ), 
#  keras.layers.Conv2DTranspose(8, kernel_size=3, strides=2, padding="SAME", activation="selu" ), 
 keras.layers.MaxPool2D((2, 2)),
 keras.layers.Flatten(),
 keras.layers.Dense(512, activation="selu", input_shape=[30]),
 keras.layers.Dense(256,activation='selu'),
 keras.layers.Dense(128,activation='selu'),
 keras.layers.Dense(28 * 28, activation="sigmoid"),
 keras.layers.Reshape([28, 28])
])

# %% [markdown]
# __Now connect them together__

# %%
denoising_ae = keras.models.Sequential([denoising_encoder, denoising_decoder])
denoising_ae.compile(loss="binary_crossentropy", optimizer=tf.keras.optimizers.SGD(learning_rate=1.0),
 metrics=[rounded_accuracy])

# %% [markdown]
# __Using x_train as both the inputs and the targets and similarly, we use x_valid as both the validation inputs and targets__

# %%
history = denoising_ae.fit(x_train, x_train, epochs=20,
 validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 12s 4ms/step - loss: 0.2988 - rounded_accuracy: 0.9024 - val_loss: 0.2573 - val_rounded_accuracy: 0.9285
# Epoch 2/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2436 - rounded_accuracy: 0.9371 - val_loss: 0.2373 - val_rounded_accuracy: 0.9396
# Epoch 3/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2274 - rounded_accuracy: 0.9455 - val_loss: 0.2256 - val_rounded_accuracy: 0.9461
# Epoch 4/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2182 - rounded_accuracy: 0.9496 - val_loss: 0.2188 - val_rounded_accuracy: 0.9483
# Epoch 5/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.2123 - rounded_accuracy: 0.9523 - val_loss: 0.2140 - val_rounded_accuracy: 0.9507
# Epoch 6/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.2082 - rounded_accuracy: 0.9540 - val_loss: 0.2091 - val_rounded_accuracy: 0.9528
# Epoch 7/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.2049 - rounded_accuracy: 0.9554 - val_loss: 0.2095 - val_rounded_accuracy: 0.9530
# Epoch 8/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.2022 - rounded_accuracy: 0.9564 - val_loss: 0.2054 - val_rounded_accuracy: 0.9542
# Epoch 9/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1999 - rounded_accuracy: 0.9573 - val_loss: 0.2003 - val_rounded_accuracy: 0.9567
# Epoch 10/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1979 - rounded_accuracy: 0.9581 - val_loss: 0.2007 - val_rounded_accuracy: 0.9561
# Epoch 11/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1963 - rounded_accuracy: 0.9588 - val_loss: 0.2066 - val_rounded_accuracy: 0.9502
# Epoch 12/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1948 - rounded_accuracy: 0.9593 - val_loss: 0.2062 - val_rounded_accuracy: 0.9524
# Epoch 13/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1935 - rounded_accuracy: 0.9598 - val_loss: 0.2019 - val_rounded_accuracy: 0.9560
# Epoch 14/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1924 - rounded_accuracy: 0.9603 - val_loss: 0.1983 - val_rounded_accuracy: 0.9576
# Epoch 15/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1913 - rounded_accuracy: 0.9607 - val_loss: 0.1965 - val_rounded_accuracy: 0.9577
# Epoch 16/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1904 - rounded_accuracy: 0.9611 - val_loss: 0.1930 - val_rounded_accuracy: 0.9604
# Epoch 17/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1894 - rounded_accuracy: 0.9616 - val_loss: 0.1968 - val_rounded_accuracy: 0.9577
# Epoch 18/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1887 - rounded_accuracy: 0.9619 - val_loss: 0.1947 - val_rounded_accuracy: 0.9586
# Epoch 19/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1879 - rounded_accuracy: 0.9621 - val_loss: 0.1926 - val_rounded_accuracy: 0.9599
# Epoch 20/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1871 - rounded_accuracy: 0.9625 - val_loss: 0.1930 - val_rounded_accuracy: 0.9582

# %% [markdown]
# ### Reconstruction Zone & Analysis

# %% [markdown]
# __Function to show plots__

# %%
def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")

# %% [markdown]
# __Function to Reconstruction Images given a model__

# %%
def show_reconstructions(model, images=x_valid, n_images=5):
    reconstructions = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])

# %% [markdown]
# __Top is Original & Bottom is Reconstructed__

# %%
show_reconstructions(denoising_ae)

# %% [markdown]
# __Analysis__

# %% [markdown]
# __t-SNE is based on probability distributions with random walk on neighborhood graphs to find the structure
# within the data.__

# %%
np.random.seed(42)
from sklearn.manifold import TSNE
X_valid_compressed = denoising_ae.predict(x_valid)
nsamples, nx, ny = X_valid_compressed.shape
X_valid_compressed = X_valid_compressed.reshape((nsamples,nx*ny))
tsne = TSNE()
X_valid_2D = tsne.fit_transform(X_valid_compressed)
X_valid_2D = (X_valid_2D - X_valid_2D.min()) / (X_valid_2D.max() - X_valid_2D.min())
# Out:
# C:\Users\Michael\miniconda3\envs\py3_base\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Michael\miniconda3\envs\py3_base\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# __t-SNE Plot__

# %%
plt.scatter(X_valid_2D[:, 0], X_valid_2D[:, 1], c=y_valid, s=10, cmap="tab10")
plt.axis("off")
plt.show()

# %% [markdown]
# __t-SNE with Images__

# %%
import matplotlib as mpl
plt.figure(figsize=(10, 8))
cmap = plt.cm.tab10
plt.scatter(X_valid_2D[:, 0], X_valid_2D[:, 1], c=y_valid, s=10, cmap=cmap)
image_positions = np.array([[1., 1.]])
for index, position in enumerate(X_valid_2D):
    dist = np.sum((position - image_positions) ** 2, axis=1)
    if np.min(dist) > 0.02: # if far enough from other images
            image_positions = np.r_[image_positions, [position]]
            imagebox = mpl.offsetbox.AnnotationBbox(
                mpl.offsetbox.OffsetImage(x_valid[index], cmap="binary"),
                position, bboxprops={"edgecolor": cmap(y_valid[index]), "lw": 2})
    plt.gca().add_artist(imagebox)
plt.axis("off")
plt.show()
