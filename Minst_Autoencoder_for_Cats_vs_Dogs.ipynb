# %% [markdown]
# __Imports__

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import keras
import tensorflow_datasets as tfds

# %% [markdown]
# ### Load in the data__
# * Splits the data
# * Shuffle the data

# %% [markdown]
# __Batch_size=-1 to get the full dataset in NumPy arrays from the returned tf.Tensor object__

# %%
mnist_test,mnist_val,mnist_train = tfds.load(name="beans",
                                             split=["train[:10%]", "train[10%:25%]", "train[25%:]"],
                                             batch_size=-1,
                                             shuffle_files=True
                                            )

# %% [markdown]
# __tfds.as_numpy return a generator that yields NumPy array records out of a tf.data.Dataset__

# %%
# tfds.as_numpy return a generator that yields NumPy array records out of a tf.data.Dataset
mnist_train = tfds.as_numpy(mnist_train) 
mnist_val = tfds.as_numpy(mnist_val) 
mnist_test = tfds.as_numpy(mnist_test)

# %% [markdown]
# __Seperate the x and y__

# %%
x_train, y_train = mnist_train["image"], mnist_train["label"]
x_valid,y_valid = mnist_val["image"], mnist_val["label"]
x_test, y_test = mnist_test["image"], mnist_test["label"]

# %% [markdown]
# __Check lengths__

# %%
print("Train set size: ", len(x_train))
print("Valid set size: ", len(x_valid))
print("Test set size: ", len(x_test))
# Out:
# Train set size:  776
# Valid set size:  155
# Test set size:  103

# %% [markdown]
# __Data Normalization__

# %% [markdown]
# __Convert Images to RGB to grayscale & Resizing__

# %%
def resize_img(img):
    IMG_SIZE = 28
    resize_and_rescale = tf.keras.Sequential([
    keras.layers.Resizing(IMG_SIZE, IMG_SIZE),
    keras.layers.Rescaling(1./255)
    ])
    return resize_and_rescale(img)

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# %%
# from PIL import Image
# def rgb_to_img(img):
# #     R, G, B = img[:,:,0], img[:,:,1], img[:,:,2]
# #     imgGray = 0.2989 * R + 0.5870 * G + 0.1140 * B
#     imgGray = img.convert('L')
#     return imgGray
# plt.imshow(imgGray, cmap='gray')
# plt.show()
# print(imgGray.shape)

# %%
resizer = lambda img: resize_img(img)
rgb_2_gray = lambda img: rgb2gray(img)

# %%
x_train = resizer(x_train)

# %%
x_train[0].shape
# Out:
# TensorShape([28, 28, 3])

# %%
x_train = rgb_2_gray(x_train)

# %%
x_train[0].shape
# Out:
# (28, 28)

# %% [markdown]
# __Visualize the Data__

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(x_train[i], cmap=plt.cm.binary, interpolation='nearest')
    # label the image with the target value
    ax.text(0, 7, str(y_train[i]))

# %%
x_train.shape
# Out:
# (776, 28, 28)

# %% [markdown]
# ### Processing Data

# %% [markdown]
# __Accuracy Function__

# %%
def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

# %% [markdown]
# __Always a good habit to randomized seeds__

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# __Autoencoder Model__

# %% [markdown]
# __Encoder__

# %%
stacked_encoder = keras.models.Sequential([
    keras.layers.Input(shape=(28,28,1)),
    keras.layers.Conv2D( filters=16, kernel_size=3, 
                        padding="SAME",
                        activation="selu" ),
    keras.layers.MaxPool2D(pool_size=2),
    keras.layers.Conv2D( filters=32, kernel_size=3, 
                        padding="SAME",
                        activation="selu" ),
    keras.layers.MaxPool2D(pool_size=2),
    keras.layers.Conv2D( filters=64, kernel_size=3, 
                        padding="SAME",
                        activation="selu" ),
    keras.layers.MaxPool2D(pool_size=2)
])
stacked_encoder.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 16)        160
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          18496
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
# =================================================================
# Total params: 23,296
# Trainable params: 23,296
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Decoder__

# %%
stacked_decoder = keras.models.Sequential([
    # padding="VALID" since 3*2 !=7
    keras.layers.Conv2DTranspose( 32, kernel_size=3, 
                                 strides=2, padding="VALID",
                                 activation="selu", input_shape=[3,3,64]), #==> (None, 7, 7, 32)
    # 7x2 (strides)=14 and padding=0
    keras.layers.Conv2DTranspose( 16, kernel_size=3, strides=2, padding="SAME",
                                 activation="selu" ), #==> (None, 14, 14, 16)
    # 14x2(strides)=28
    keras.layers.Conv2DTranspose( 1, kernel_size=3, strides=2, padding="SAME", 
                                 activation="sigmoid" ), #==> (None, 28, 28, 1)
    keras.layers.Reshape([28,28])
])
stacked_decoder.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_transpose (Conv2DTra  (None, 7, 7, 32)         18464
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 14, 14, 16)       4624
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 28, 28, 1)        145
#  ranspose)
#
#  reshape (Reshape)           (None, 28, 28)            0
#
# =================================================================
# Total params: 23,233
# Trainable params: 23,233
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Now connect them together__

# %%
stacked_ae = keras.models.Sequential([stacked_encoder, stacked_decoder])

# %% [markdown]
# __Binary cross-entropy loss: each pixel(or each label) intensity represents the probability that the pixel should so model converges faster__

# %%
stacked_ae.compile(loss="binary_crossentropy",
                   optimizer=tf.keras.optimizers.SGD(learning_rate=1.5), 
                   metrics=[rounded_accuracy])

# %% [markdown]
# __Using x_train as both the inputs and the targets and similarly, we use x_valid as both the validation inputs and targets__

# %%
history = stacked_ae.fit(x_train, x_train,
                         epochs=20,
                         validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/20
# 25/25 [==============================] - ETA: 0s - loss: 0.6916 - rounded_accuracy: 0.5496WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='sequential_3_input'), name='sequential_3_input', description="created by layer 'sequential_3_input'"), but it was called on an input with incompatible shape (None, 500, 500, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='sequential_3_input'), name='sequential_3_input', description="created by layer 'sequential_3_input'"), but it was called on an input with incompatible shape (None, 500, 500, 3).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 history = stacked_ae.fit(x_train, x_train,
#       2                          epochs=20,
#       3                          validation_data=(x_valid, x_valid))
#
# File ~\miniconda3\envs\py3_base\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\miniconda3\envs\py3_base\lib\site-packages\tensorflow\python\framework\func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
# -> 1147     raise e.ag_error_metadata.to_exception(e)
#    1148   else:
#    1149     raise
#
# ValueError: in user code:
#
#     File "C:\Users\Michael\miniconda3\envs\py3_base\lib\site-packages\keras\engine\training.py", line 1525, in test_function  *
#         return step_function(self, iterator)
#     File "C:\Users\Michael\miniconda3\envs\py3_base\lib\site-packages\keras\engine\training.py", line 1514, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Michael\miniconda3\envs\py3_base\lib\site-packages\keras\engine\training.py", line 1507, in run_step  **
#         outputs = model.test_step(data)
#     File "C:\Users\Michael\miniconda3\envs\py3_base\lib\site-packages\keras\engine\training.py", line 1471, in test_step
#         y_pred = self(x, training=False)
#     File "C:\Users\Michael\miniconda3\envs\py3_base\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Michael\miniconda3\envs\py3_base\lib\site-packages\keras\engine\input_spec.py", line 264, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Exception encountered when calling layer "sequential_5" (type Sequential).
#
#     Input 0 of layer "sequential_3" is incompatible with the layer: expected shape=(None, 28, 28, 1), found shape=(None, 500, 500, 3)
#
#     Call arguments received:
#       • inputs=tf.Tensor(shape=(None, 500, 500, 3), dtype=uint8)
#       • training=False
#       • mask=None

# %% [markdown]
# ### Reconstruction Zone & Analysis

# %% [markdown]
# __Function to show plots__

# %%
def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")

# %% [markdown]
# __Function to Reconstruction Images given a model__

# %%
def show_reconstructions(model, images=x_valid, n_images=5):
    reconstructions = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])

# %% [markdown]
# __Top is Original & Bottom is Reconstructed__

# %%
show_reconstructions(stacked_ae)

# %% [markdown]
# __Analysis__

# %% [markdown]
# __t-SNE is based on probability distributions with random walk on neighborhood graphs to find the structure
# within the data.__

# %%
np.random.seed(42)
from sklearn.manifold import TSNE
X_valid_compressed = stacked_ae.predict(x_valid)
nsamples, nx, ny,oth = X_valid_compressed.shape
X_valid_compressed = X_valid_compressed.reshape((nsamples,nx*ny))
tsne = TSNE()
X_valid_2D = tsne.fit_transform(X_valid_compressed)
X_valid_2D = (X_valid_2D - X_valid_2D.min()) / (X_valid_2D.max() - X_valid_2D.min())

# %% [markdown]
# __t-SNE Plot__

# %%
plt.scatter(X_valid_2D[:, 0], X_valid_2D[:, 1], c=y_valid, s=10, cmap="tab10")
plt.axis("off")
plt.show()

# %% [markdown]
# __t-SNE with Images__

# %%
import matplotlib as mpl
plt.figure(figsize=(10, 8))
cmap = plt.cm.tab10
plt.scatter(X_valid_2D[:, 0], X_valid_2D[:, 1], c=y_valid, s=10, cmap=cmap)
image_positions = np.array([[1., 1.]])
for index, position in enumerate(X_valid_2D):
    dist = np.sum((position - image_positions) ** 2, axis=1)
    if np.min(dist) > 0.02: # if far enough from other images
            image_positions = np.r_[image_positions, [position]]
            imagebox = mpl.offsetbox.AnnotationBbox(
                mpl.offsetbox.OffsetImage(x_valid[index], cmap="binary"),
                position, bboxprops={"edgecolor": cmap(y_valid[index]), "lw": 2})
    plt.gca().add_artist(imagebox)
plt.axis("off")
plt.show()
