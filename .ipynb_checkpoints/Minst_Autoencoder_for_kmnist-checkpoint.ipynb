# %% [markdown]
# __Imports__

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import keras
import tensorflow_datasets as tfds

# %% [markdown]
# ### Load in the data__
# * Splits the data
# * Shuffle the data

# %% [markdown]
# __Batch_size=-1 to get the full dataset in NumPy arrays from the returned tf.Tensor object__

# %%
mnist_test,mnist_val,mnist_train = tfds.load(name="kmnist",
                                             split=["train[:10%]", "train[10%:25%]", "train[25%:]"],
                                             batch_size=-1,
                                             shuffle_files=True
                                            )
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to C:\Users\Michael\tensorflow_datasets\kmnist\3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling C:\Users\Michael\tensorflow_datasets\kmnist\3.0.1.incompleteSPKL12\kmnist-train.tfrecord*...:   0%| …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling C:\Users\Michael\tensorflow_datasets\kmnist\3.0.1.incompleteSPKL12\kmnist-test.tfrecord*...:   0%|  …
# Dataset kmnist downloaded and prepared to C:\Users\Michael\tensorflow_datasets\kmnist\3.0.1. Subsequent calls will reuse this data.

# %% [markdown]
# __tfds.as_numpy return a generator that yields NumPy array records out of a tf.data.Dataset__

# %%
# tfds.as_numpy return a generator that yields NumPy array records out of a tf.data.Dataset
mnist_train = tfds.as_numpy(mnist_train) 
mnist_val = tfds.as_numpy(mnist_val) 
mnist_test = tfds.as_numpy(mnist_test)

# %% [markdown]
# __Seperate the x and y__

# %%
x_train, y_train = mnist_train["image"], mnist_train["label"]
x_valid,y_valid = mnist_val["image"], mnist_val["label"]
x_test, y_test = mnist_test["image"], mnist_test["label"]

# %% [markdown]
# __Check lengths__

# %%
print("Train set size: ", len(x_train))
print("Valid set size: ", len(x_valid))
print("Test set size: ", len(x_test))
# Out:
# Train set size:  45000
# Valid set size:  9000
# Test set size:  6000

# %% [markdown]
# __Data Normalization__

# %% [markdown]
# __Convert Images to RGB to grayscale & Resizing__

# %%
def resize_img(img):
    IMG_SIZE = 64
    resize_and_rescale = tf.keras.Sequential([
    keras.layers.Resizing(IMG_SIZE, IMG_SIZE),
    keras.layers.Rescaling(1./255)
    ])
    return resize_and_rescale(img)

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# %%
resizer = lambda img: resize_img(img)
rgb_2_gray = lambda img: rgb2gray(img)

# %%
x_train = resizer(x_train)
x_valid = resizer(x_valid)
x_test = resizer(x_test)

# %%
x_train[0].shape
# Out:
# TensorShape([64, 64, 1])

# %%
x_train[0].shape

# %% [markdown]
# __Visualize the Data__

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(x_train[i], cmap=plt.cm.binary, interpolation='nearest')
    # label the image with the target value
    ax.text(0, 7, str(y_train[i]))

# %%
x_train.shape
# Out:
# TensorShape([45000, 64, 64, 1])

# %% [markdown]
# ### Processing Data

# %% [markdown]
# __Accuracy Function__

# %%
def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

# %% [markdown]
# __Always a good habit to randomized seeds__

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# __Autoencoder Model__

# %% [markdown]
# __Encoder__

# %%
stacked_encoder = keras.models.Sequential([
    keras.layers.Input(shape=(64,64,1)),
    keras.layers.Conv2D( filters=16, kernel_size=3, 
                        padding="SAME",
                        activation="selu" ),
    keras.layers.MaxPool2D(pool_size=2),
    keras.layers.Conv2D( filters=32, kernel_size=3, 
                        padding="SAME",
                        activation="selu" ),
    keras.layers.MaxPool2D(pool_size=2),
    keras.layers.Conv2D( filters=64, kernel_size=3, 
                        padding="SAME",
                        activation="selu" ),
    keras.layers.MaxPool2D(pool_size=2)
])
stacked_encoder.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
# =================================================================
# Total params: 23,296
# Trainable params: 23,296
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Decoder__

# %%
stacked_decoder = keras.models.Sequential([
    # padding="VALID" since 3*2 !=7
    keras.layers.Conv2DTranspose( 32, kernel_size=4, 
                                 strides=2, padding="SAME",
                                 activation="selu", input_shape=[8,8,64]), #==> (None, 7, 7, 32)
    # 7x2 (strides)=14 and padding=0
    keras.layers.Conv2DTranspose( 16, kernel_size=3, strides=2, padding="SAME",
                                 activation="selu" ), #==> (None, 14, 14, 16)
    # 14x2(strides)=28
    keras.layers.Conv2DTranspose( 1, kernel_size=3, strides=2, padding="SAME", 
                                 activation="sigmoid" ), #==> (None, 28, 28, 1)
    keras.layers.Reshape([64,64])
])
stacked_decoder.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_transpose (Conv2DTra  (None, 16, 16, 32)       32800
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 16)       4624
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 64, 64, 1)        145
#  ranspose)
#
#  reshape (Reshape)           (None, 64, 64)            0
#
# =================================================================
# Total params: 37,569
# Trainable params: 37,569
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Now connect them together__

# %%
stacked_ae = keras.models.Sequential([stacked_encoder, stacked_decoder])

# %% [markdown]
# __Binary cross-entropy loss: each pixel(or each label) intensity represents the probability that the pixel should so model converges faster__

# %%
stacked_ae.compile(loss="binary_crossentropy",
                   optimizer=tf.keras.optimizers.SGD(learning_rate=1.5), 
                   metrics=[rounded_accuracy])

# %% [markdown]
# __Using x_train as both the inputs and the targets and similarly, we use x_valid as both the validation inputs and targets__

# %%
history = stacked_ae.fit(x_train, x_train,
                         epochs=20,
                         validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 14s 4ms/step - loss: 0.1833 - rounded_accuracy: 0.9641 - val_loss: 0.1649 - val_rounded_accuracy: 0.9769
# Epoch 2/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1623 - rounded_accuracy: 0.9793 - val_loss: 0.1616 - val_rounded_accuracy: 0.9809
# Epoch 3/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1606 - rounded_accuracy: 0.9813 - val_loss: 0.1601 - val_rounded_accuracy: 0.9825
# Epoch 4/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1598 - rounded_accuracy: 0.9824 - val_loss: 0.1591 - val_rounded_accuracy: 0.9841
# Epoch 5/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1592 - rounded_accuracy: 0.9833 - val_loss: 0.1588 - val_rounded_accuracy: 0.9846
# Epoch 6/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1587 - rounded_accuracy: 0.9840 - val_loss: 0.1583 - val_rounded_accuracy: 0.9855
# Epoch 7/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1584 - rounded_accuracy: 0.9845 - val_loss: 0.1586 - val_rounded_accuracy: 0.9843
# Epoch 8/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1581 - rounded_accuracy: 0.9849 - val_loss: 0.1597 - val_rounded_accuracy: 0.9819
# Epoch 9/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1579 - rounded_accuracy: 0.9852 - val_loss: 0.1580 - val_rounded_accuracy: 0.9858
# Epoch 10/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1577 - rounded_accuracy: 0.9855 - val_loss: 0.1583 - val_rounded_accuracy: 0.9843
# Epoch 11/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1575 - rounded_accuracy: 0.9858 - val_loss: 0.1574 - val_rounded_accuracy: 0.9867
# Epoch 12/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1574 - rounded_accuracy: 0.9860 - val_loss: 0.1605 - val_rounded_accuracy: 0.9797
# Epoch 13/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1572 - rounded_accuracy: 0.9862 - val_loss: 0.1586 - val_rounded_accuracy: 0.9843
# Epoch 14/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1571 - rounded_accuracy: 0.9864 - val_loss: 0.1572 - val_rounded_accuracy: 0.9868
# Epoch 15/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1570 - rounded_accuracy: 0.9866 - val_loss: 0.1573 - val_rounded_accuracy: 0.9870
# Epoch 16/20
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1569 - rounded_accuracy: 0.9867 - val_loss: 0.1570 - val_rounded_accuracy: 0.9873
# Epoch 17/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1568 - rounded_accuracy: 0.9869 - val_loss: 0.1567 - val_rounded_accuracy: 0.9877
# Epoch 18/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1567 - rounded_accuracy: 0.9870 - val_loss: 0.1566 - val_rounded_accuracy: 0.9878
# Epoch 19/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1566 - rounded_accuracy: 0.9871 - val_loss: 0.1565 - val_rounded_accuracy: 0.9879
# Epoch 20/20
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1565 - rounded_accuracy: 0.9873 - val_loss: 0.1573 - val_rounded_accuracy: 0.9860

# %% [markdown]
# ### Reconstruction Zone & Analysis

# %% [markdown]
# __Function to show plots__

# %%
def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")

# %% [markdown]
# __Function to Reconstruction Images given a model__

# %%
def show_reconstructions(model, images=x_valid, n_images=5):
    reconstructions = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])

# %% [markdown]
# __Top is Original & Bottom is Reconstructed__

# %%
show_reconstructions(stacked_ae)

# %% [markdown]
# __Analysis__

# %% [markdown]
# __t-SNE is based on probability distributions with random walk on neighborhood graphs to find the structure
# within the data.__

# %%
np.random.seed(42)
from sklearn.manifold import TSNE
X_valid_compressed = stacked_ae.predict(x_valid)
nsamples, nx, ny = X_valid_compressed.shape
X_valid_compressed = X_valid_compressed.reshape((nsamples,nx*ny))
tsne = TSNE()
X_valid_2D = tsne.fit_transform(X_valid_compressed)
X_valid_2D = (X_valid_2D - X_valid_2D.min()) / (X_valid_2D.max() - X_valid_2D.min())
# Out:
# C:\Users\Michael\miniconda3\envs\py3_base\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Michael\miniconda3\envs\py3_base\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# __t-SNE Plot__

# %%
plt.scatter(X_valid_2D[:, 0], X_valid_2D[:, 1], c=y_valid, s=10, cmap="tab10")
plt.axis("off")
plt.show()

# %% [markdown]
# __t-SNE with Images__

# %%
import matplotlib as mpl
plt.figure(figsize=(10, 8))
cmap = plt.cm.tab10
plt.scatter(X_valid_2D[:, 0], X_valid_2D[:, 1], c=y_valid, s=10, cmap=cmap)
image_positions = np.array([[1., 1.]])
for index, position in enumerate(X_valid_2D):
    dist = np.sum((position - image_positions) ** 2, axis=1)
    if np.min(dist) > 0.02: # if far enough from other images
            image_positions = np.r_[image_positions, [position]]
            imagebox = mpl.offsetbox.AnnotationBbox(
                mpl.offsetbox.OffsetImage(x_valid[index], cmap="binary"),
                position, bboxprops={"edgecolor": cmap(y_valid[index]), "lw": 2})
    plt.gca().add_artist(imagebox)
plt.axis("off")
plt.show()
